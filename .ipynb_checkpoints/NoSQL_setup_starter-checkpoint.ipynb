# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --db 'uk_food' --collection 'establishments' --file 'establishments.json' --jsonArray`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f6f4e10fb06f2af23ef11'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
query = establishments.find_one({'BusinessName':'Penang Flavours'})
pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f6f6ad020fcca16755826'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

establishments.find_one(query, fields)
# Out:
# {'_id': ObjectId('662f6f4e10fb06f2af23ef11'),
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
   {"BusinessName": "Penang Flavours"},
    {'$set': 
        {'BusinessTypeID': 1}
    }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': "Penang Flavours"}
pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f6f6ad020fcca16755826'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}

# Print the number of results
print("Number of documents in result:", establishments.count_documents(query))
# Out:
# Number of documents in result: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check if any remaining documents include Dover
print("Number of documents in result:", establishments.count_documents(query))
# Out:
# Number of documents in result: 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f6f4e10fb06f2af23f1f6'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many( {}, [{'$set': {'geocode.longitude': {'$toDecimal': '$geocode.longitude'},
                                   'geocode.latitude': {'$toDecimal': '$geocode.latitude'}   } }] )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many( {}, [{'$set': {'RatingValue': {'$toInt': '$RatingValue'}}} ] )

# %%
# Check that the coordinates and rating value are now numbers
query = {}
fields = {'geocode.longitude': 1, 'geocode.latitude': 1, 'RatingValue': 1}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1f6'),
#  'geocode': {'latitude': Decimal128('51.086058'),
#              'longitude': Decimal128('1.196408')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1f7'),
#  'geocode': {'latitude': Decimal128('51.085797'),
#              'longitude': Decimal128('1.194762')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1f8'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1fb'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1fc'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f1fe'),
#  'geocode': {'latitude': Decimal128('51.08084'),
#              'longitude': Decimal128('1.188537')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f200'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f201'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f202'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f203'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f204'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f205'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f206'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f207'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f208'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f209'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20a'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20b'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20c'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20d'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20e'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f20f'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f210'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f211'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f212'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f213'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f214'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f215'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f216'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f217'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f218'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f219'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21a'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21b'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21c'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21d'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21e'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f21f'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f220'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f221'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f222'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f223'),
#  'geocode': {'latitude': Decimal128('51.0805695006979'),
#              'longitude': Decimal128('1.18794649942731')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f224'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f226'),
#  'geocode': {'latitude': Decimal128('51.0783519967076'),
#              'longitude': Decimal128('1.18590330311705')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f227'),
#  'geocode': {'latitude': Decimal128('51.078449'),
#              'longitude': Decimal128('1.18516')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f228'),
#  'geocode': {'latitude': Decimal128('51.080673'),
#              'longitude': Decimal128('1.187083')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f229'),
#  'geocode': {'latitude': Decimal128('51.095015'),
#              'longitude': Decimal128('1.202055')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f22a'),
#  'geocode': {'latitude': Decimal128('51.080446'),
#              'longitude': Decimal128('1.186825')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f22b'),
#  'geocode': {'latitude': Decimal128('51.080284'),
#              'longitude': Decimal128('1.186485')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f22d'),
#  'geocode': {'latitude': Decimal128('51.079985650005'),
#              'longitude': Decimal128('1.18628335007084')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f22f'),
#  'geocode': {'latitude': Decimal128('51.079613'),
#              'longitude': Decimal128('1.185368')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f230'),
#  'geocode': {'latitude': Decimal128('51.079613'),
#              'longitude': Decimal128('1.185368')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f231'),
#  'geocode': {'latitude': Decimal128('51.077971'),
#              'longitude': Decimal128('1.183585')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f233'),
#  'geocode': {'latitude': Decimal128('51.083232'),
#              'longitude': Decimal128('1.188902')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f234'),
#  'geocode': {'latitude': Decimal128('51.081735'),
#              'longitude': Decimal128('1.187056')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f235'),
#  'geocode': {'latitude': Decimal128('51.080838'),
#              'longitude': Decimal128('1.186309')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f236'),
#  'geocode': {'latitude': Decimal128('51.07915'),
#              'longitude': Decimal128('1.184194')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f237'),
#  'geocode': {'latitude': Decimal128('51.081546'),
#              'longitude': Decimal128('1.186715')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f238'),
#  'geocode': {'latitude': Decimal128('51.07915'),
#              'longitude': Decimal128('1.184194')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f23a'),
#  'geocode': {'latitude': Decimal128('51.0803'),
#              'longitude': Decimal128('1.184916')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f23b'),
#  'geocode': {'latitude': Decimal128('51.086262'),
#              'longitude': Decimal128('1.190896')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f23c'),
#  'geocode': {'latitude': Decimal128('51.080224'),
#              'longitude': Decimal128('1.186067')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f23d'),
#  'geocode': {'latitude': Decimal128('51.080284'),
#              'longitude': Decimal128('1.186485')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f23e'),
#  'geocode': {'latitude': Decimal128('51.087887'),
#              'longitude': Decimal128('1.194306')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f240'),
#  'geocode': {'latitude': Decimal128('51.0818061828613'),
#              'longitude': Decimal128('1.18601894378662')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f242'),
#  'geocode': {'latitude': Decimal128('51.0877821'),
#              'longitude': Decimal128('1.1920251')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f244'),
#  'geocode': {'latitude': Decimal128('51.0804748535156'),
#              'longitude': Decimal128('1.18425798416138')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f245'),
#  'geocode': {'latitude': Decimal128('51.0804824829102'),
#              'longitude': Decimal128('1.18421399593353')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f246'),
#  'geocode': {'latitude': Decimal128('51.0804824829102'),
#              'longitude': Decimal128('1.18421399593353')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f247'),
#  'geocode': {'latitude': Decimal128('51.079301'),
#              'longitude': Decimal128('1.182962')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f248'),
#  'geocode': {'latitude': Decimal128('51.0793'),
#              'longitude': Decimal128('1.182962')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f249'),
#  'geocode': {'latitude': Decimal128('51.0809478759766'),
#              'longitude': Decimal128('1.18431901931763')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24a'),
#  'geocode': {'latitude': Decimal128('51.080956'),
#              'longitude': Decimal128('1.18429')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24b'),
#  'geocode': {'latitude': Decimal128('51.080956'),
#              'longitude': Decimal128('1.18429')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24c'),
#  'geocode': {'latitude': Decimal128('51.080956'),
#              'longitude': Decimal128('1.18429')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24d'),
#  'geocode': {'latitude': Decimal128('51.0917365039471'),
#              'longitude': Decimal128('1.19522100055125')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24e'),
#  'geocode': {'latitude': Decimal128('51.080956'),
#              'longitude': Decimal128('1.18429')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f24f'),
#  'geocode': {'latitude': Decimal128('51.097794'),
#              'longitude': Decimal128('1.201433')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f250'),
#  'geocode': {'latitude': Decimal128('51.080804'),
#              'longitude': Decimal128('1.183893')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f251'),
#  'geocode': {'latitude': Decimal128('51.080805'),
#              'longitude': Decimal128('1.183894')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f252'),
#  'geocode': {'latitude': Decimal128('51.079905'),
#              'longitude': Decimal128('1.182875')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f253'),
#  'geocode': {'latitude': Decimal128('51.08034'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f254'),
#  'geocode': {'latitude': Decimal128('51.0810258'),
#              'longitude': Decimal128('1.1835476')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f255'),
#  'geocode': {'latitude': Decimal128('51.080339'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f256'),
#  'geocode': {'latitude': Decimal128('51.080339'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f257'),
#  'geocode': {'latitude': Decimal128('51.0802956'),
#              'longitude': Decimal128('1.1823865')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f258'),
#  'geocode': {'latitude': Decimal128('51.08034'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f259'),
#  'geocode': {'latitude': Decimal128('51.08034'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25a'),
#  'geocode': {'latitude': Decimal128('51.079542'),
#              'longitude': Decimal128('1.181365')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25b'),
#  'geocode': {'latitude': Decimal128('51.079532623291'),
#              'longitude': Decimal128('1.1813759803772')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25c'),
#  'geocode': {'latitude': Decimal128('51.079889'),
#              'longitude': Decimal128('1.181832')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25d'),
#  'geocode': {'latitude': Decimal128('51.0803409'),
#              'longitude': Decimal128('1.1822069')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25e'),
#  'geocode': {'latitude': Decimal128('51.079542'),
#              'longitude': Decimal128('1.181365')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f25f'),
#  'geocode': {'latitude': Decimal128('51.0798931'),
#              'longitude': Decimal128('1.1817077')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f260'),
#  'geocode': {'latitude': Decimal128('51.079542'),
#              'longitude': Decimal128('1.181365')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f261'),
#  'geocode': {'latitude': Decimal128('51.080412'),
#              'longitude': Decimal128('1.182125')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f262'),
#  'geocode': {'latitude': Decimal128('51.08034'),
#              'longitude': Decimal128('1.182805')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f263'),
#  'geocode': {'latitude': Decimal128('51.078209'),
#              'longitude': Decimal128('1.179446')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f264'),
#  'geocode': {'latitude': Decimal128('51.080412'),
#              'longitude': Decimal128('1.182125')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f265'),
#  'geocode': {'latitude': Decimal128('51.0798'),
#              'longitude': Decimal128('1.181483')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f267'),
#  'geocode': {'latitude': Decimal128('51.089491'),
#              'longitude': Decimal128('1.190904')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f268'),
#  'geocode': {'latitude': Decimal128('51.0806732177734'),
#              'longitude': Decimal128('1.18172800540924')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f269'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26a'),
#  'geocode': {'latitude': Decimal128('51.0800235'),
#              'longitude': Decimal128('1.1813097')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26b'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26c'),
#  'geocode': {'latitude': Decimal128('51.0802346'),
#              'longitude': Decimal128('1.1814856')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26d'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26e'),
#  'geocode': {'latitude': Decimal128('51.089491'),
#              'longitude': Decimal128('1.190904')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f26f'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f270'),
#  'geocode': {'latitude': Decimal128('51.0806941'),
#              'longitude': Decimal128('1.1817227')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f271'),
#  'geocode': {'latitude': Decimal128('51.082322'),
#              'longitude': Decimal128('1.183327')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f272'),
#  'geocode': {'latitude': Decimal128('51.0793698'),
#              'longitude': Decimal128('1.1802781')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f273'),
#  'geocode': {'latitude': Decimal128('51.08164'),
#              'longitude': Decimal128('1.182609')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f274'),
#  'geocode': {'latitude': Decimal128('51.083976'),
#              'longitude': Decimal128('1.185011')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f275'),
#  'geocode': {'latitude': Decimal128('51.08164'),
#              'longitude': Decimal128('1.182609')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f276'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f277'),
#  'geocode': {'latitude': Decimal128('51.080675'),
#              'longitude': Decimal128('1.181728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f278'),
#  'geocode': {'latitude': Decimal128('51.07954'),
#              'longitude': Decimal128('1.180437')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f279'),
#  'geocode': {'latitude': Decimal128('51.07954'),
#              'longitude': Decimal128('1.180437')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27a'),
#  'geocode': {'latitude': Decimal128('51.07954'),
#              'longitude': Decimal128('1.180437')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27b'),
#  'geocode': {'latitude': Decimal128('51.07954'),
#              'longitude': Decimal128('1.180437')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27c'),
#  'geocode': {'latitude': Decimal128('51.079799'),
#              'longitude': Decimal128('1.181482')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27d'),
#  'geocode': {'latitude': Decimal128('51.0816612'),
#              'longitude': Decimal128('1.1826116')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27e'),
#  'geocode': {'latitude': Decimal128('51.08472'),
#              'longitude': Decimal128('1.185748')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f27f'),
#  'geocode': {'latitude': Decimal128('51.084721'),
#              'longitude': Decimal128('1.185748')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f280'),
#  'geocode': {'latitude': Decimal128('51.0818634033203'),
#              'longitude': Decimal128('1.18279695510864')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f281'),
#  'geocode': {'latitude': Decimal128('51.080417'),
#              'longitude': Decimal128('1.181282')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f282'),
#  'geocode': {'latitude': Decimal128('51.0797886'),
#              'longitude': Decimal128('1.1810166')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f283'),
#  'geocode': {'latitude': Decimal128('51.080417'),
#              'longitude': Decimal128('1.181282')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f284'),
#  'geocode': {'latitude': Decimal128('51.0804176330566'),
#              'longitude': Decimal128('1.18128204345703')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f285'),
#  'geocode': {'latitude': Decimal128('51.08187'),
#              'longitude': Decimal128('1.182753')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f286'),
#  'geocode': {'latitude': Decimal128('51.08187'),
#              'longitude': Decimal128('1.182753')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f287'),
#  'geocode': {'latitude': Decimal128('51.081494'),
#              'longitude': Decimal128('1.182356')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f288'),
#  'geocode': {'latitude': Decimal128('51.080181'),
#              'longitude': Decimal128('1.181023')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f289'),
#  'geocode': {'latitude': Decimal128('51.08187'),
#              'longitude': Decimal128('1.182753')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28a'),
#  'geocode': {'latitude': Decimal128('51.086189'),
#              'longitude': Decimal128('1.186977')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28b'),
#  'geocode': {'latitude': Decimal128('51.086189'),
#              'longitude': Decimal128('1.186977')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28c'),
#  'geocode': {'latitude': Decimal128('51.0785865783691'),
#              'longitude': Decimal128('1.17911505699158')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28d'),
#  'geocode': {'latitude': Decimal128('51.078587'),
#              'longitude': Decimal128('1.179115')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28e'),
#  'geocode': {'latitude': Decimal128('51.078296'),
#              'longitude': Decimal128('1.178909')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f28f'),
#  'geocode': {'latitude': Decimal128('51.0780695'),
#              'longitude': Decimal128('1.1785097')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f290'),
#  'geocode': {'latitude': Decimal128('51.078296'),
#              'longitude': Decimal128('1.178909')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f291'),
#  'geocode': {'latitude': Decimal128('51.0798709'),
#              'longitude': Decimal128('1.1803396')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f292'),
#  'geocode': {'latitude': Decimal128('51.0802287'),
#              'longitude': Decimal128('1.1806797')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f293'),
#  'geocode': {'latitude': Decimal128('51.0781968'),
#              'longitude': Decimal128('1.1783613')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f294'),
#  'geocode': {'latitude': Decimal128('51.078117'),
#              'longitude': Decimal128('1.1784815')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f295'),
#  'geocode': {'latitude': Decimal128('51.085454'),
#              'longitude': Decimal128('1.186241')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f296'),
#  'geocode': {'latitude': Decimal128('51.0781968'),
#              'longitude': Decimal128('1.1783613')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f297'),
#  'geocode': {'latitude': Decimal128('51.079632'),
#              'longitude': Decimal128('1.179729')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f298'),
#  'geocode': {'latitude': Decimal128('51.079632'),
#              'longitude': Decimal128('1.179729')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f299'),
#  'geocode': {'latitude': Decimal128('51.083569'),
#              'longitude': Decimal128('1.183784')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29a'),
#  'geocode': {'latitude': Decimal128('51.083569'),
#              'longitude': Decimal128('1.183784')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29b'),
#  'geocode': {'latitude': Decimal128('51.080315'),
#              'longitude': Decimal128('1.18039')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29c'),
#  'geocode': {'latitude': Decimal128('51.078296'),
#              'longitude': Decimal128('1.178909')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29d'),
#  'geocode': {'latitude': Decimal128('51.078296'),
#              'longitude': Decimal128('1.178909')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29e'),
#  'geocode': {'latitude': Decimal128('51.080315'),
#              'longitude': Decimal128('1.18039')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f29f'),
#  'geocode': {'latitude': Decimal128('51.0818613'),
#              'longitude': Decimal128('1.1818685')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a0'),
#  'geocode': {'latitude': Decimal128('51.0818613'),
#              'longitude': Decimal128('1.1818685')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a2'),
#  'geocode': {'latitude': Decimal128('51.080211'),
#              'longitude': Decimal128('1.179926')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a4'),
#  'geocode': {'latitude': Decimal128('51.080211'),
#              'longitude': Decimal128('1.179925')}}
# {'RatingValue': 1,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a5'),
#  'geocode': {'latitude': Decimal128('51.080217'),
#              'longitude': Decimal128('1.1799178')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a6'),
#  'geocode': {'latitude': Decimal128('51.080211'),
#              'longitude': Decimal128('1.179926')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a7'),
#  'geocode': {'latitude': Decimal128('51.079161'),
#              'longitude': Decimal128('1.17884')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a8'),
#  'geocode': {'latitude': Decimal128('51.081526'),
#              'longitude': Decimal128('1.181201')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2a9'),
#  'geocode': {'latitude': Decimal128('51.079481'),
#              'longitude': Decimal128('1.178961')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2aa'),
#  'geocode': {'latitude': Decimal128('51.079482'),
#              'longitude': Decimal128('1.178962')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ab'),
#  'geocode': {'latitude': Decimal128('51.078131'),
#              'longitude': Decimal128('1.178027')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ac'),
#  'geocode': {'latitude': Decimal128('51.081337'),
#              'longitude': Decimal128('1.180846')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ad'),
#  'geocode': {'latitude': Decimal128('51.079482'),
#              'longitude': Decimal128('1.178962')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ae'),
#  'geocode': {'latitude': Decimal128('51.081337'),
#              'longitude': Decimal128('1.180846')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2af'),
#  'geocode': {'latitude': Decimal128('51.0783483'),
#              'longitude': Decimal128('1.177752')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b1'),
#  'geocode': {'latitude': Decimal128('51.0824157'),
#              'longitude': Decimal128('1.1817418')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b2'),
#  'geocode': {'latitude': Decimal128('51.078317'),
#              'longitude': Decimal128('1.177468')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b3'),
#  'geocode': {'latitude': Decimal128('51.078317'),
#              'longitude': Decimal128('1.177468')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b4'),
#  'geocode': {'latitude': Decimal128('51.078317'),
#              'longitude': Decimal128('1.177468')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b5'),
#  'geocode': {'latitude': Decimal128('51.078317'),
#              'longitude': Decimal128('1.177468')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b6'),
#  'geocode': {'latitude': Decimal128('51.082867'),
#              'longitude': Decimal128('1.182136')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b7'),
#  'geocode': {'latitude': Decimal128('51.082867'),
#              'longitude': Decimal128('1.182136')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2b9'),
#  'geocode': {'latitude': Decimal128('51.087132'),
#              'longitude': Decimal128('1.186371')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ba'),
#  'geocode': {'latitude': Decimal128('51.0806446'),
#              'longitude': Decimal128('1.1796215')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2bb'),
#  'geocode': {'latitude': Decimal128('51.080669'),
#              'longitude': Decimal128('1.179629')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2bc'),
#  'geocode': {'latitude': Decimal128('51.080669'),
#              'longitude': Decimal128('1.179629')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2bd'),
#  'geocode': {'latitude': Decimal128('51.080668'),
#              'longitude': Decimal128('1.179628')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2be'),
#  'geocode': {'latitude': Decimal128('51.076896'),
#              'longitude': Decimal128('1.175486')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2bf'),
#  'geocode': {'latitude': Decimal128('51.0783433'),
#              'longitude': Decimal128('1.1776046')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c0'),
#  'geocode': {'latitude': Decimal128('51.088735'),
#              'longitude': Decimal128('1.188295')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c1'),
#  'geocode': {'latitude': Decimal128('51.0804496'),
#              'longitude': Decimal128('1.1794011')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c2'),
#  'geocode': {'latitude': Decimal128('51.083108'),
#              'longitude': Decimal128('1.181896')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c3'),
#  'geocode': {'latitude': Decimal128('51.0808513'),
#              'longitude': Decimal128('1.1794486')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c4'),
#  'geocode': {'latitude': Decimal128('51.078211'),
#              'longitude': Decimal128('1.176733')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c5'),
#  'geocode': {'latitude': Decimal128('51.0782127380371'),
#              'longitude': Decimal128('1.17673301696777')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c6'),
#  'geocode': {'latitude': Decimal128('51.0810699462891'),
#              'longitude': Decimal128('1.17957198619843')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c7'),
#  'geocode': {'latitude': Decimal128('51.088735'),
#              'longitude': Decimal128('1.188295')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c8'),
#  'geocode': {'latitude': Decimal128('51.079081'),
#              'longitude': Decimal128('1.177506')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2c9'),
#  'geocode': {'latitude': Decimal128('51.079081'),
#              'longitude': Decimal128('1.177506')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ca'),
#  'geocode': {'latitude': Decimal128('51.080624'),
#              'longitude': Decimal128('1.178969')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2cb'),
#  'geocode': {'latitude': Decimal128('51.079679'),
#              'longitude': Decimal128('1.17799')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2cc'),
#  'geocode': {'latitude': Decimal128('51.079679'),
#              'longitude': Decimal128('1.17799')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2cd'),
#  'geocode': {'latitude': Decimal128('51.079679'),
#              'longitude': Decimal128('1.17799')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ce'),
#  'geocode': {'latitude': Decimal128('51.079679'),
#              'longitude': Decimal128('1.17799')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2cf'),
#  'geocode': {'latitude': Decimal128('51.076653'),
#              'longitude': Decimal128('1.174813')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d0'),
#  'geocode': {'latitude': Decimal128('51.0776252746582'),
#              'longitude': Decimal128('1.17575001716614')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d1'),
#  'geocode': {'latitude': Decimal128('51.077626'),
#              'longitude': Decimal128('1.17575')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d2'),
#  'geocode': {'latitude': Decimal128('51.077626'),
#              'longitude': Decimal128('1.17575')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d3'),
#  'geocode': {'latitude': Decimal128('51.077626'),
#              'longitude': Decimal128('1.17575')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d4'),
#  'geocode': {'latitude': Decimal128('51.077626'),
#              'longitude': Decimal128('1.17575')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d5'),
#  'geocode': {'latitude': Decimal128('51.077626'),
#              'longitude': Decimal128('1.17575')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d6'),
#  'geocode': {'latitude': Decimal128('51.076956'),
#              'longitude': Decimal128('1.174605')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d7'),
#  'geocode': {'latitude': Decimal128('51.076956'),
#              'longitude': Decimal128('1.174605')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d8'),
#  'geocode': {'latitude': Decimal128('51.07879'),
#              'longitude': Decimal128('1.176258')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2d9'),
#  'geocode': {'latitude': Decimal128('51.078718'),
#              'longitude': Decimal128('1.176296')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2da'),
#  'geocode': {'latitude': Decimal128('51.078513'),
#              'longitude': Decimal128('1.175897')}}
# {'RatingValue': 1,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2db'),
#  'geocode': {'latitude': Decimal128('51.087185'),
#              'longitude': Decimal128('1.185418')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2dc'),
#  'geocode': {'latitude': Decimal128('51.078718'),
#              'longitude': Decimal128('1.176296')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2dd'),
#  'geocode': {'latitude': Decimal128('51.078033'),
#              'longitude': Decimal128('1.17535')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2de'),
#  'geocode': {'latitude': Decimal128('51.0788531'),
#              'longitude': Decimal128('1.1762215')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2df'),
#  'geocode': {'latitude': Decimal128('51.078033'),
#              'longitude': Decimal128('1.17535')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e0'),
#  'geocode': {'latitude': Decimal128('51.078033'),
#              'longitude': Decimal128('1.17535')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e1'),
#  'geocode': {'latitude': Decimal128('51.078515'),
#              'longitude': Decimal128('1.175811')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e2'),
#  'geocode': {'latitude': Decimal128('51.078033'),
#              'longitude': Decimal128('1.17535')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e3'),
#  'geocode': {'latitude': Decimal128('51.078033'),
#              'longitude': Decimal128('1.17535')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e4'),
#  'geocode': {'latitude': Decimal128('51.0787391662598'),
#              'longitude': Decimal128('1.17591404914856')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e5'),
#  'geocode': {'latitude': Decimal128('51.09221'),
#              'longitude': Decimal128('1.189834')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e6'),
#  'geocode': {'latitude': Decimal128('51.078515'),
#              'longitude': Decimal128('1.175811')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e7'),
#  'geocode': {'latitude': Decimal128('51.09221'),
#              'longitude': Decimal128('1.189833')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e8'),
#  'geocode': {'latitude': Decimal128('51.0758056640625'),
#              'longitude': Decimal128('1.17352676391602')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2e9'),
#  'geocode': {'latitude': Decimal128('51.0776458'),
#              'longitude': Decimal128('1.1753663')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ea'),
#  'geocode': {'latitude': Decimal128('51.087382'),
#              'longitude': Decimal128('1.184803')}}
# {'RatingValue': 1,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2eb'),
#  'geocode': {'latitude': Decimal128('51.07873'),
#              'longitude': Decimal128('1.17584')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ec'),
#  'geocode': {'latitude': Decimal128('51.07873'),
#              'longitude': Decimal128('1.17584')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ed'),
#  'geocode': {'latitude': Decimal128('51.07873'),
#              'longitude': Decimal128('1.17584')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ee'),
#  'geocode': {'latitude': Decimal128('51.07873'),
#              'longitude': Decimal128('1.17584')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2ef'),
#  'geocode': {'latitude': Decimal128('51.0812644958496'),
#              'longitude': Decimal128('1.17841398715973')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f0'),
#  'geocode': {'latitude': Decimal128('51.0806630002457'),
#              'longitude': Decimal128('1.17725700019713')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f1'),
#  'geocode': {'latitude': Decimal128('51.076647'),
#              'longitude': Decimal128('1.172728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f2'),
#  'geocode': {'latitude': Decimal128('51.076647'),
#              'longitude': Decimal128('1.172728')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f3'),
#  'geocode': {'latitude': Decimal128('51.076647'),
#              'longitude': Decimal128('1.172728')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f4'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f5'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f6'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f7'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4e10fb06f2af23f2f8'),
#  'geocode': {'latitude': Decimal128('51.0881644'),
#              'longitude': Decimal128('1.1842719')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2f9'),
#  'geocode': {'latitude': Decimal128('51.076413'),
#              'longitude': Decimal128('1.172055')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2fa'),
#  'geocode': {'latitude': Decimal128('51.07856'),
#              'longitude': Decimal128('1.1748')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2fb'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2fc'),
#  'geocode': {'latitude': Decimal128('51.088115'),
#              'longitude': Decimal128('1.18431')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2fd'),
#  'geocode': {'latitude': Decimal128('51.079039'),
#              'longitude': Decimal128('1.174748')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2fe'),
#  'geocode': {'latitude': Decimal128('51.077492'),
#              'longitude': Decimal128('1.173056')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f2ff'),
#  'geocode': {'latitude': Decimal128('51.080171'),
#              'longitude': Decimal128('1.175782')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f300'),
#  'geocode': {'latitude': Decimal128('51.090286'),
#              'longitude': Decimal128('1.185859')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f301'),
#  'geocode': {'latitude': Decimal128('51.077414'),
#              'longitude': Decimal128('1.172652')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4f10fb06f2af23f302'),
#  'geocode': {'latitude': Decimal128('51.076577'),
#              'longitude': Decimal128('1.17198')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f303'),
#  'geocode': {'latitude': Decimal128('51.089337'),
#              'longitude': Decimal128('1.18468')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f304'),
#  'geocode': {'latitude': Decimal128('51.0833323'),
#              'longitude': Decimal128('1.1784191')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f305'),
#  'geocode': {'latitude': Decimal128('51.077702'),
#              'longitude': Decimal128('1.172314')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4f10fb06f2af23f306'),
#  'geocode': {'latitude': Decimal128('51.091129'),
#              'longitude': Decimal128('1.186289')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f307'),
#  'geocode': {'latitude': Decimal128('51.074167'),
#              'longitude': Decimal128('1.16866')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f309'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30a'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30b'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30c'),
#  'geocode': {'latitude': Decimal128('51.077414'),
#              'longitude': Decimal128('1.172652')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30d'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30e'),
#  'geocode': {'latitude': Decimal128('51.076577'),
#              'longitude': Decimal128('1.17198')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f30f'),
#  'geocode': {'latitude': Decimal128('51.080171'),
#              'longitude': Decimal128('1.175782')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f310'),
#  'geocode': {'latitude': Decimal128('51.088333'),
#              'longitude': Decimal128('1.183925')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f311'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f312'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f313'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f4f10fb06f2af23f314'),
#  'geocode': {'latitude': Decimal128('51.078197'),
#              'longitude': Decimal128('1.172619')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f4f10fb06f2af23f315'),
#  'geocode': {'latitude': Decimal128('51.082871'),
#              'longitude': Decimal128('1.177367')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f316'),
#  'geocode': {'latitude': Decimal128('51.079192'),
#              'longitude': Decimal128('1.173416')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f317'),
#  'geocode': {'latitude': Decimal128('51.078068'),
#              'longitude': Decimal128('1.172054')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f318'),
#  'geocode': {'latitude': Decimal128('51.082381'),
#              'longitude': Decimal128('1.176219')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f319'),
#  'geocode': {'latitude': Decimal128('51.078885'),
#              'longitude': Decimal128('1.172452')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31a'),
#  'geocode': {'latitude': Decimal128('51.081154'),
#              'longitude': Decimal128('1.174678')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31b'),
#  'geocode': {'latitude': Decimal128('51.078874'),
#              'longitude': Decimal128('1.171552')}}
# {'RatingValue': 2,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31c'),
#  'geocode': {'latitude': Decimal128('51.088893'),
#              'longitude': Decimal128('1.181507')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31d'),
#  'geocode': {'latitude': Decimal128('51.085038'),
#              'longitude': Decimal128('1.177729')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31e'),
#  'geocode': {'latitude': Decimal128('51.08129'),
#              'longitude': Decimal128('1.17363')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f31f'),
#  'geocode': {'latitude': Decimal128('51.081291'),
#              'longitude': Decimal128('1.173631')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f320'),
#  'geocode': {'latitude': Decimal128('51.077243'),
#              'longitude': Decimal128('1.168984')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f321'),
#  'geocode': {'latitude': Decimal128('51.0819'),
#              'longitude': Decimal128('1.17373')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f4f10fb06f2af23f322'),
#  'geocode': {'latitude': Decimal128('51.086485'),
#              'longitude': Decimal128('1.178428')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f4f10fb06f2af23f323'),
#  'geocode': {'latitude': Decimal128('51.081291'),
# ...
#  '_id': ObjectId('662f6f5010fb06f2af2439f8'),
#  'geocode': {'latitude': Decimal128('51.900771'),
#              'longitude': Decimal128('0.892428')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af2439f9'),
#  'geocode': {'latitude': Decimal128('51.418403'),
#              'longitude': Decimal128('0.394657')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f5010fb06f2af2439fa'),
#  'geocode': {'latitude': Decimal128('51.38603'),
#              'longitude': Decimal128('0.362194')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af2439fb'),
#  'geocode': {'latitude': Decimal128('51.874738'),
#              'longitude': Decimal128('0.864777')}}
# {'RatingValue': 1,
#  '_id': ObjectId('662f6f5010fb06f2af2439fc'),
#  'geocode': {'latitude': Decimal128('51.900772'),
#              'longitude': Decimal128('0.892429')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af2439fd'),
#  'geocode': {'latitude': Decimal128('51.900772'),
#              'longitude': Decimal128('0.892429')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af2439fe'),
#  'geocode': {'latitude': Decimal128('51.833959'),
#              'longitude': Decimal128('0.822078')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af2439ff'),
#  'geocode': {'latitude': Decimal128('51.8814353942871'),
#              'longitude': Decimal128('0.871582984924316')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a00'),
#  'geocode': {'latitude': Decimal128('51.903061'),
#              'longitude': Decimal128('0.894393')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a01'),
#  'geocode': {'latitude': Decimal128('51.422208'),
#              'longitude': Decimal128('0.398596')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a02'),
#  'geocode': {'latitude': Decimal128('51.873074'),
#              'longitude': Decimal128('0.86255')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a03'),
#  'geocode': {'latitude': Decimal128('51.873074'),
#              'longitude': Decimal128('0.86255')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a04'),
#  'geocode': {'latitude': Decimal128('51.4183559'),
#              'longitude': Decimal128('0.3938766')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a05'),
#  'geocode': {'latitude': Decimal128('51.885167'),
#              'longitude': Decimal128('0.875207')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a06'),
#  'geocode': {'latitude': Decimal128('51.885167'),
#              'longitude': Decimal128('0.875207')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a07'),
#  'geocode': {'latitude': Decimal128('51.64126'),
#              'longitude': Decimal128('0.621662')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a08'),
#  'geocode': {'latitude': Decimal128('51.418366'),
#              'longitude': Decimal128('0.39385')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a09'),
#  'geocode': {'latitude': Decimal128('51.418366'),
#              'longitude': Decimal128('0.39385')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a0a'),
#  'geocode': {'latitude': Decimal128('51.418366'),
#              'longitude': Decimal128('0.39385')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a0b'),
#  'geocode': {'latitude': Decimal128('51.572905'),
#              'longitude': Decimal128('0.551307')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a0c'),
#  'geocode': {'latitude': Decimal128('51.412269'),
#              'longitude': Decimal128('0.387649')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a0d'),
#  'geocode': {'latitude': Decimal128('51.874738'),
#              'longitude': Decimal128('0.864777')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a0e'),
#  'geocode': {'latitude': Decimal128('51.572905'),
#              'longitude': Decimal128('0.551307')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a0f'),
#  'geocode': {'latitude': Decimal128('51.572905'),
#              'longitude': Decimal128('0.551307')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a10'),
#  'geocode': {'latitude': Decimal128('51.768361'),
#              'longitude': Decimal128('0.753028')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a11'),
#  'geocode': {'latitude': Decimal128('51.027384'),
#              'longitude': Decimal128('0.002638')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a12'),
#  'geocode': {'latitude': Decimal128('51.570908'),
#              'longitude': Decimal128('0.548871')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a13'),
#  'geocode': {'latitude': Decimal128('51.2032241821289'),
#              'longitude': Decimal128('0.176614999771118')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a14'),
#  'geocode': {'latitude': Decimal128('51.2032241821289'),
#              'longitude': Decimal128('0.176614999771118')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a15'),
#  'geocode': {'latitude': Decimal128('51.888312'),
#              'longitude': Decimal128('0.877559')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a16'),
#  'geocode': {'latitude': Decimal128('51.8733253479004'),
#              'longitude': Decimal128('0.861840009689331')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f5010fb06f2af243a17'),
#  'geocode': {'latitude': Decimal128('51.873325'),
#              'longitude': Decimal128('0.86184')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a18'),
#  'geocode': {'latitude': Decimal128('51.900772'),
#              'longitude': Decimal128('0.892429')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a19'),
#  'geocode': {'latitude': Decimal128('51.386029'),
#              'longitude': Decimal128('0.362193')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a1a'),
#  'geocode': {'latitude': Decimal128('51.874738'),
#              'longitude': Decimal128('0.864777')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a1b'),
#  'geocode': {'latitude': Decimal128('51.903062'),
#              'longitude': Decimal128('0.894393')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a1c'),
#  'geocode': {'latitude': Decimal128('51.877712'),
#              'longitude': Decimal128('0.866347')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a1d'),
#  'geocode': {'latitude': Decimal128('51.90964'),
#              'longitude': Decimal128('0.899353')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a1e'),
#  'geocode': {'latitude': Decimal128('51.90964'),
#              'longitude': Decimal128('0.899353')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a1f'),
#  'geocode': {'latitude': Decimal128('51.90964'),
#              'longitude': Decimal128('0.899353')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a20'),
#  'geocode': {'latitude': Decimal128('51.90964'),
#              'longitude': Decimal128('0.899353')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a21'),
#  'geocode': {'latitude': Decimal128('51.662434'),
#              'longitude': Decimal128('0.642334')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a22'),
#  'geocode': {'latitude': Decimal128('51.902739'),
#              'longitude': Decimal128('0.892147')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a23'),
#  'geocode': {'latitude': Decimal128('51.0718078613281'),
#              'longitude': Decimal128('0.0453349985182285')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a24'),
#  'geocode': {'latitude': Decimal128('51.0718193054199'),
#              'longitude': Decimal128('0.0453240014612675')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a25'),
#  'geocode': {'latitude': Decimal128('51.0718193054199'),
#              'longitude': Decimal128('0.0453240014612675')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a26'),
#  'geocode': {'latitude': Decimal128('51.635237'),
#              'longitude': Decimal128('0.6139')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a27'),
#  'geocode': {'latitude': Decimal128('51.3843574523926'),
#              'longitude': Decimal128('0.357796013355255')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a28'),
#  'geocode': {'latitude': Decimal128('51.635237'),
#              'longitude': Decimal128('0.6139')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a29'),
#  'geocode': {'latitude': Decimal128('51.3844085'),
#              'longitude': Decimal128('0.3576589')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a2a'),
#  'geocode': {'latitude': Decimal128('51.912378'),
#              'longitude': Decimal128('0.901696')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a2b'),
#  'geocode': {'latitude': Decimal128('51.947912'),
#              'longitude': Decimal128('0.939036')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a2c'),
#  'geocode': {'latitude': Decimal128('51.418254'),
#              'longitude': Decimal128('0.392737')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a2d'),
#  'geocode': {'latitude': Decimal128('51.239353'),
#              'longitude': Decimal128('0.2114')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a2e'),
#  'geocode': {'latitude': Decimal128('51.9101753234863'),
#              'longitude': Decimal128('0.899213016033173')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a2f'),
#  'geocode': {'latitude': Decimal128('51.9101753234863'),
#              'longitude': Decimal128('0.899213016033173')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a30'),
#  'geocode': {'latitude': Decimal128('51.04939'),
#              'longitude': Decimal128('0.022492')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a31'),
#  'geocode': {'latitude': Decimal128('51.876803'),
#              'longitude': Decimal128('0.864153')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a32'),
#  'geocode': {'latitude': Decimal128('51.906312'),
#              'longitude': Decimal128('0.894966')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f5010fb06f2af243a33'),
#  'geocode': {'latitude': Decimal128('51.919559'),
#              'longitude': Decimal128('0.909184')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a34'),
#  'geocode': {'latitude': Decimal128('51.9055144'),
#              'longitude': Decimal128('0.8952778')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a35'),
#  'geocode': {'latitude': Decimal128('51.947912'),
#              'longitude': Decimal128('0.939036')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a36'),
#  'geocode': {'latitude': Decimal128('51.38482'),
#              'longitude': Decimal128('0.357504')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a37'),
#  'geocode': {'latitude': Decimal128('51.7659538'),
#              'longitude': Decimal128('0.7482549')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a38'),
#  'geocode': {'latitude': Decimal128('51.8713150024414'),
#              'longitude': Decimal128('0.85801899433136')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a39'),
#  'geocode': {'latitude': Decimal128('51.418254'),
#              'longitude': Decimal128('0.392737')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a3a'),
#  'geocode': {'latitude': Decimal128('51.9119588898163'),
#              'longitude': Decimal128('0.90053')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a3b'),
#  'geocode': {'latitude': Decimal128('51.9119588898163'),
#              'longitude': Decimal128('0.90053')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a3c'),
#  'geocode': {'latitude': Decimal128('51.924583'),
#              'longitude': Decimal128('0.913642')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a3d'),
#  'geocode': {'latitude': Decimal128('51.771322'),
#              'longitude': Decimal128('0.753354')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a3e'),
#  'geocode': {'latitude': Decimal128('51.771322'),
#              'longitude': Decimal128('0.753354')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a3f'),
#  'geocode': {'latitude': Decimal128('51.198733'),
#              'longitude': Decimal128('0.1698143')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a40'),
#  'geocode': {'latitude': Decimal128('51.771322'),
#              'longitude': Decimal128('0.753354')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a41'),
#  'geocode': {'latitude': Decimal128('51.333042'),
#              'longitude': Decimal128('0.304355')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a42'),
#  'geocode': {'latitude': Decimal128('51.033199'),
#              'longitude': Decimal128('0.00547')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a43'),
#  'geocode': {'latitude': Decimal128('51.878867'),
#              'longitude': Decimal128('0.867277')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a44'),
#  'geocode': {'latitude': Decimal128('51.411842'),
#              'longitude': Decimal128('0.383902')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a45'),
#  'geocode': {'latitude': Decimal128('51.411842'),
#              'longitude': Decimal128('0.383902')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a46'),
#  'geocode': {'latitude': Decimal128('51.7665367126465'),
#              'longitude': Decimal128('0.747551023960114')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a47'),
#  'geocode': {'latitude': Decimal128('51.72994'),
#              'longitude': Decimal128('0.709416')}}
# {'RatingValue': 4,
#  '_id': ObjectId('662f6f5010fb06f2af243a48'),
#  'geocode': {'latitude': Decimal128('51.888351'),
#              'longitude': Decimal128('0.874451')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a49'),
#  'geocode': {'latitude': Decimal128('51.906861'),
#              'longitude': Decimal128('0.893852')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4a'),
#  'geocode': {'latitude': Decimal128('51.882266998291'),
#              'longitude': Decimal128('0.868016004562378')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4b'),
#  'geocode': {'latitude': Decimal128('51.2870805'),
#              'longitude': Decimal128('0.2572915')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4c'),
#  'geocode': {'latitude': Decimal128('51.2870805'),
#              'longitude': Decimal128('0.2572915')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4d'),
#  'geocode': {'latitude': Decimal128('51.72994'),
#              'longitude': Decimal128('0.709416')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4e'),
#  'geocode': {'latitude': Decimal128('51.8807094'),
#              'longitude': Decimal128('0.8663176')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a4f'),
#  'geocode': {'latitude': Decimal128('51.643541'),
#              'longitude': Decimal128('0.619813')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a50'),
#  'geocode': {'latitude': Decimal128('51.5736656188965'),
#              'longitude': Decimal128('0.547867000102997')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a51'),
#  'geocode': {'latitude': Decimal128('51.039451'),
#              'longitude': Decimal128('0.01059')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a52'),
#  'geocode': {'latitude': Decimal128('51.880187'),
#              'longitude': Decimal128('0.865545')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a53'),
#  'geocode': {'latitude': Decimal128('51.577659'),
#              'longitude': Decimal128('0.551457')}}
# {'RatingValue': None,
#  '_id': ObjectId('662f6f5010fb06f2af243a54'),
#  'geocode': {'latitude': Decimal128('51.913508'),
#              'longitude': Decimal128('0.900024')}}
# {'RatingValue': 3,
#  '_id': ObjectId('662f6f5010fb06f2af243a55'),
#  'geocode': {'latitude': Decimal128('51.913508'),
#              'longitude': Decimal128('0.900024')}}
# {'RatingValue': 5,
#  '_id': ObjectId('662f6f5010fb06f2af243a56'),
#  'geocode': {'latitude': Decimal128('51.8806754'),
#              'longitude':
